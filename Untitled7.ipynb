# %%
import numpy as np

# %%
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3, 1))
# Out:
# array([[1.],
#        [1.],
#        [1.]])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0, 1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.transpose
# Out:
# <function transpose at 0x78edff5302b0>

# %%
np.concatenate
# Out:
# <function concatenate at 0x78ee054c4930>

# %%
np.array([1, 2, 3]) # [1 2 3]
# Out:
# array([1, 2, 3])

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.concatenate(([1, 2], [3, 4]))
# Out:
# array([1, 2, 3, 4])

# %%
np.logspace(1, 3, 3)
# Out:
# array([  10.,  100., 1000.])

# %%
np.diag([1, 2, 3])
# Out:
# array([[1, 0, 0],
#        [0, 2, 0],
#        [0, 0, 3]])

# %%
np.random.rand(2, 3)
# Out:
# array([[0.73115838, 0.62290513, 0.4231294 ],
#        [0.72188628, 0.82878671, 0.64707781]])

# %%
np.random.randint(1, 100, size=5)
# Out:
# array([10, 94, 23, 87, 92])

# %%
np.vstack(([1, 2], [3, 4]))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.vstack(([1, 2], [3, 4]))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.split(np.arange(6), 3)
# Out:
# [array([0, 1]), array([2, 3]), array([4, 5])]

# %%
np.expand_dims(np.array([1, 2]), axis=0)
# Out:
# array([[1, 2]])

# %%
np.squeeze(np.array([[[1, 2]]]))
# Out:
# array([1, 2])

# %%
 np.array([1, 5, 2, 8])
# Out:
# array([1, 5, 2, 8])

# %%
np.clip(2, 3, 7)
# Out:
# np.int64(3)

# %%
np.power([2, 3], [3, 2])
# Out:
# array([8, 9])

# %%
np.cumsum([1, 2, 3, 4])
# Out:
# array([ 1,  3,  6, 10])

# %%
np.diff([1, 2, 4, 7])
# Out:
# array([1, 2, 3])

# %%
np.round([1.23, 2.78], decimals=1)
# Out:
# array([1.2, 2.8])

# %%
np.unique([1, 1, 2, 3, 3])
# Out:
# array([1, 2, 3])

# %%
np.intersect1d([1, 2, 3], [2, 3, 4])
# Out:
# array([2, 3])

# %%
np.union1d([1, 2], [2, 3])
# Out:
# array([1, 2, 3])

# %%
np.in1d([1, 2, 3], [2, 4])
# Out:
# /tmp/ipykernel_1170/1015789951.py:1: DeprecationWarning: `in1d` is deprecated. Use `np.isin` instead.
#   np.in1d([1, 2, 3], [2, 4])
# array([False,  True, False])
